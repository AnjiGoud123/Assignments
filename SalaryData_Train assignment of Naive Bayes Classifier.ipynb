# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("SalaryData_Train.csv.crdownload")
df
# Out:
#        age          workclass      education  educationno  \
# 0       39          State-gov      Bachelors           13
# 1       50   Self-emp-not-inc      Bachelors           13
# 2       38            Private        HS-grad            9
# 3       53            Private           11th            7
# 4       28            Private      Bachelors           13
# ...    ...                ...            ...          ...
# 14111   42   Self-emp-not-inc        HS-grad            9
# 14112   23            Private        HS-grad            9
# 14113   28            Private      Bachelors           13
# 14114   20            Private        HS-grad            9
# 14115   22            Private   Some-college           10
#
#              maritalstatus          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14116 entries, 0 to 14115
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            14116 non-null  int64
#  1   workclass      14116 non-null  object
#  2   education      14116 non-null  object
#  3   educationno    14116 non-null  int64
#  4   maritalstatus  14116 non-null  object
#  5   occupation     14116 non-null  object
#  6   relationship   14116 non-null  object
#  7   race           14116 non-null  object
#  8   sex            14116 non-null  object
#  9   capitalgain    14116 non-null  int64
#  10  capitalloss    14116 non-null  int64
#  11  hoursperweek   14116 non-null  int64
#  12  native         14116 non-null  object
#  13  Salary         14115 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.5+ MB

# %%
df.shape
# Out:
# (14116, 14)

# %%
df.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  14116.000000  14116.000000  14116.000000  14116.000000  14116.000000
# mean      38.378152     10.128011   1074.678379     87.684755     40.960400
# std       13.124120      2.533651   7336.366087    401.022825     11.908188
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       47.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
df.duplicated().sum()
# Out:
# 896

# %%
df.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           1
# dtype: int64

# %%
df.drop_duplicates()
df.drop_duplicates(inplace=True)
df
# Out:
#        age          workclass      education  educationno  \
# 0       39          State-gov      Bachelors           13
# 1       50   Self-emp-not-inc      Bachelors           13
# 2       38            Private        HS-grad            9
# 3       53            Private           11th            7
# 4       28            Private      Bachelors           13
# ...    ...                ...            ...          ...
# 14109   30          State-gov      Bachelors           13
# 14110   59            Private        HS-grad            9
# 14111   42   Self-emp-not-inc        HS-grad            9
# 14113   28            Private      Bachelors           13
# 14115   22            Private   Some-college           10
#
#              maritalstatus          occupation     relationship    race  \
# 0            Never-married        Adm-clerical    Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial          Husband   White
# ...

# %%
# Handling missing data
df.dropna()
df.dropna(inplace=True)
df
# Out:
#        age          workclass   education  educationno        maritalstatus  \
# 0       39          State-gov   Bachelors           13        Never-married
# 1       50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2       38            Private     HS-grad            9             Divorced
# 3       53            Private        11th            7   Married-civ-spouse
# 4       28            Private   Bachelors           13   Married-civ-spouse
# ...    ...                ...         ...          ...                  ...
# 14108   54            Private     HS-grad            9   Married-civ-spouse
# 14109   30          State-gov   Bachelors           13        Never-married
# 14110   59            Private     HS-grad            9   Married-civ-spouse
# 14111   42   Self-emp-not-inc     HS-grad            9             Divorced
# 14113   28            Private   Bachelors           13   Married-civ-spouse
#
# ...

# %%
df.shape
# Out:
# (13219, 14)

# %%
df['Salary'].value_counts()
# Out:
#  <=50K    9907
#  >50K     3312
# Name: Salary, dtype: int64

# %%
# apply label encoding for all variables
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df["workclass"] = LE.fit_transform(df["workclass"])
df["education"] = LE.fit_transform(df["education"])
df["maritalstatus"] = LE.fit_transform(df["maritalstatus"])
df["occupation"] = LE.fit_transform(df["occupation"])
df["relationship"] = LE.fit_transform(df["relationship"])
df["race"] = LE.fit_transform(df["race"])
df["sex"] = LE.fit_transform(df["sex"])
df["native"] = LE.fit_transform(df["native"])

# %%
pd.pandas.set_option('display.max_columns',None)

# %%
df
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 14108   54          2         11            9              2          11
# 14109   30          5          9           13              4           9
# 14110   59          2         11            9              2          13
# 14111   42          4         11            9              0           3
# 14113   28          2          9           13              2           7
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
df.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
# split the variables as X and Y
X =df.iloc[:,0:13]
Y = df["Salary"]

# %%
# Data partition
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y)

# %%
X_train.shape
# Out:
# (9914, 13)

# %%
Y_train.shape
# Out:
# (9914,)

# %%
X_test.shape
# Out:
# (3305, 13)

# %%
Y_test.shape
# Out:
# (3305,)

# %%
# Model fitting
from sklearn.naive_bayes import MultinomialNB
MNB = MultinomialNB()

MNB.fit(X_train,Y_train)

Y_pred_train =  MNB.predict(X_train)
Y_pred_test = MNB.predict(X_test)

# %%
# metrics
from sklearn.metrics import accuracy_score
train_accuracy = accuracy_score(Y_train,Y_pred_train) 
test_accuracy = accuracy_score(Y_test,Y_pred_test)

print("Naive Bayes: training:",train_accuracy.round(2))
print("Naive Bayes: testing:",test_accuracy.round(2))
# Out:
# Naive Bayes: training: 0.77
# Naive Bayes: testing: 0.76
